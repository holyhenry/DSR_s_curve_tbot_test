# %%
import bagpy
from bagpy import bagreader
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize

# %matplotlib inline
# %matplotlib widget
# Out:
# /opt/ros/noetic/lib/python3/dist-packages/rosbag/bag.py:1568: SyntaxWarning: invalid escape sequence '\d'
#   matches = re.match("#ROS(.*) V(\d).(\d)", version_line)

# %%
def read_time_from_bag(bag, name_topic):
    df = pd.read_csv(bag.message_by_topic(name_topic))
    
    # try to get a time axis; fall back to sample index
    if {'header.stamp.secs', 'header.stamp.nsecs'}.issubset(df.columns):
        t = (df['header.stamp.secs'].to_numpy(dtype=float) +
             df['header.stamp.nsecs'].to_numpy(dtype=float) * 1e-9)
    else:
        print('[Warning] No matching time header found')
        t = np.arange(len(df), dtype=float)

    print(f"read time {name_topic}", t.shape)
    return t

def read_pose_from_bag(bag, name_topic, name_x, name_y):
    df = pd.read_csv(bag.message_by_topic(name_topic))
    
    # try to get a time axis; fall back to sample index
    if {'header.stamp.secs', 'header.stamp.nsecs'}.issubset(df.columns):
        t = (df['header.stamp.secs'].to_numpy(dtype=float) +
             df['header.stamp.nsecs'].to_numpy(dtype=float) * 1e-9)
    else:
        print('[Warning] No matching time header found')
        t = np.arange(len(df), dtype=float)

    pose = np.vstack([df[name_x].to_numpy(), df[name_y].to_numpy()]).T
    print(f"read pose & time {name_topic}", pose.shape)
    return t, pose

def equal_trim_to_match(t1, p1, t2, p2):
    """Evenly downsample the longer sequence to match the shorter length."""
    
    n1, n2 = len(p1), len(p2)
    if n1 == n2:
        return t1, p1, t2, p2
    if n1 > n2:
        idx = np.linspace(0, n1 - 1, n2, dtype=int)
        return t1[idx], p1[idx], t2, p2
    else:
        idx = np.linspace(0, n2 - 1, n1, dtype=int)
        return t1, p1, t2[idx], p2[idx]

# %%
# bag = bagreader('../../bag/2025-12-15-14-15-30.bag')   # [DSR, b1 0.5, b2 0.95] LSQ smooth error & lowpass 0.2 e_d (NOT SMOOTH)
bag = bagreader('../../bag/2025-12-15-14-10-51.bag')   # [DSR, b1 0.5, b2 0.90] LSQ smooth error & lowpass 0.2 e_d (GOOD)
# bag = bagreader('../../bag/2025-12-15-13-57-01.bag')   # [DSR, b1 0.8, b2 0.85] LSQ smooth error & lowpass 0.2 e_d (NOT SMOOTH)
# bag = bagreader('../../bag/2025-12-15-14-02-58.bag')   # [DSR, b1 0.6, b2 0.85] LSQ smooth error & lowpass 0.2 e_d (okay)
# bag = bagreader('../../bag/2025-12-15-13-51-25.bag')   # [DSR, b1 0.5, b2 0.85] LSQ smooth error & lowpass 0.2 e_d (GOOD)
# bag = bagreader('../../bag/2025-12-11-13-09-13.bag')   # [DSR, b1 0.5, b2 0.75] LSQ smooth error & lowpass 0.2 e_d 
# bag = bagreader('../../bag/2025-12-10-16-15-11.bag')   # [DSR, b1 0.5, b2 0.75] LSQ smooth error & lowpass 0.2 e_d 
# bag = bagreader('../../bag/2025-12-10-16-06-40.bag')   # [DSR, b1 0.5, b2 0.5] LSQ smooth error & lowpass 0.2 e_d 
# bag = bagreader('../../bag/2025-12-10-15-49-45.bag')   # LSQ smooth error & lowpass 0.2 e_d 
# bag = bagreader('../../bag/2025-12-10-15-42-32.bag')   # LSQ smooth error & e_d 
# bag = bagreader('../../bag/2025-12-09-14-40-39.bag')   # unfiltered error & e_d
# bag = bagreader('../../bag/2025-11-21-18-05-32.bag')  
# bag = bagreader('../../bag/tag_lp_test_10.bag')
print(bag.topic_table)
# Out:
# [INFO]  Data folder ../../bag/2025-12-15-14-10-51 already exists. Not creating.
#                                    Topics  \
# 0                                 /rosout
# 1                             /rosout_agg
# 2                  /tbot162/battery_state
# 3                        /tbot162/cmd_vel
# 4                  /tbot162/cmd_vel_rc100
# 5            /tbot162/controller_log_info
# 6                    /tbot162/diagnostics
# 7               /tbot162/firmware_version
# 8           /tbot162/global_leader_states
# 9                            /tbot162/imu
# 10                  /tbot162/joint_states
# 11                /tbot162/magnetic_field
# 12                          /tbot162/odom
# 13  /tbot162/robot_pose_ekf/odom_combined
# 14                  /tbot162/sensor_state
# 15                /tbot162/tag_detections
# 16                  /tbot162/version_info
# 17                     /tbot162/wheelodom
# 18                 /tbot205/battery_state
# ...

# %%
t162_tag = read_time_from_bag(bag, '/tbot162/tag_detections')
plt.figure()
plt.plot(np.diff(t162_tag-t162_tag[0]), '.', markersize='1', label='162 camera (31Hz)')
plt.legend(); plt.grid(); plt.xlabel('count'); plt.ylabel('delta t'); plt.ylim(0, 0.14)
# Out:
# read time /tbot162/tag_detections (1220,)
# (0.0, 0.14)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Leader odom v.s. Follower estimation

# %%
_, pose_205_mocap = read_pose_from_bag(bag,
                                    '/vrpn_client_node/bot205/pose',
                                    'pose.position.x',
                                    'pose.position.y')
_, pose_205_odom = read_pose_from_bag(bag,
                                    '/tbot205/odom',
                                    'pose.pose.position.x',
                                    'pose.pose.position.y')
_, pose_162_estimate = read_pose_from_bag(bag,
                                    '/tbot162/global_leader_states',
                                    'x',
                                    'y')
plt.figure()
# plt.plot(pose_205_mocap[:,0],pose_205_mocap[:,1], '.', markersize='1', label='205 mocap')
plt.plot(pose_205_odom[:,0],pose_205_odom[:,1], '.', markersize='2', label='205 odom')
plt.plot(pose_162_estimate[:,0],pose_162_estimate[:,1], '.', markersize='2', label='162 estimate')
plt.legend(); plt.grid(); plt.axis('equal'); plt.xlabel('x'); plt.ylabel('y')
# Out:
# read pose & time /vrpn_client_node/bot205/pose (5910, 2)
# read pose & time /tbot205/odom (951, 2)
# [Warning] No matching time header found
# read pose & time /tbot162/global_leader_states (1400, 2)
# Text(0, 0.5, 'y')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Odom v.s. EKF(Odom+IMU)

# %%
plt.close()

t162, p162_o = read_pose_from_bag(bag,
                                    '/tbot162/odom',
                                    'pose.pose.position.x',
                                    'pose.pose.position.y')
t162_ekf_o, p162_ekf_o = read_pose_from_bag(bag,
                                    '/tbot162/robot_pose_ekf/odom_combined',
                                    'pose.pose.position.x',
                                    'pose.pose.position.y')
plt.figure()
plt.plot(p162_o[:,0],p162_o[:,1], '.', markersize='1', label='162 odom')
plt.plot(p162_ekf_o[:,0],p162_ekf_o[:,1], '.', markersize='1', label='162 odom+imu')
plt.legend(); plt.grid(); plt.axis('equal'); plt.xlabel('x'); plt.ylabel('y')

plt.figure()
plt.plot(np.diff(t162-t162[0]), '.', markersize='1', label='162 odom (34Hz)')
plt.plot(np.diff(t162_ekf_o-t162_ekf_o[0]), '.', markersize='1', label='162 odom+imu (31Hz)')
plt.legend(); plt.grid(); plt.xlabel('count'); plt.ylabel('delta t'); plt.ylim(0, 0.15)
# Out:
# read pose & time /tbot162/odom (1506, 2)
# read pose & time /tbot162/robot_pose_ekf/odom_combined (1585, 2)
# (0.0, 0.15)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Velocity Estimation using odom

# %%
'''
Takeaway: when estimating higher order info, faster is not necessarily better!
'''

def estimate_velocity(pose_array, time, n):
    '''
    pose_array:    shape (N, k). (e.g., k=2 for 2D pose)
    time:          shape (N,)
    n:          int, window size
    '''
    return np.linalg.norm(pose_array[n:] - pose_array[:-n], axis=1), time[n:] - time[:-n]

def least_square_filter(pose_array, time, filter_buffer, tau, ROBUST_L1=False):
    '''
    pose_array:    shape (N, k). (e.g., k=2 for 2D pose)
    time:          shape (N,)|
    filter_buffer: int, window size
    tau:           float, delay time
    ROBUST_L1:     bool, enable L1 refinement
    '''    
    steps = len(pose_array)

    # initialize filter result
    velocity_f, time_f, pose_f = [], [], []

    # initialize x, y for least square
    x, y = [], []  # sliding window: x = times, y = poses

    # in controller, do...
    for i in range(steps):
        x.append(time[i])
        y.append(pose_array[i, :])

        if len(x) == filter_buffer:
            # window arrays
            t = np.asarray(x, dtype=float) # (m,)
            Y = np.asarray(y, dtype=float) # (m, k)
            k = Y.shape[1]

            A = np.vstack([t, np.ones_like(t)]).T
            C_ls = np.linalg.lstsq(A, Y, rcond=None)[0] # C_ls: (2, k)
            coeffs = C_ls

            if ROBUST_L1:   
                # Minimize sum_i ||Y_i - (a * t_i + b)||_1 over all outputs
                def L1_norm_error(theta_flat):
                    C = theta_flat.reshape(2, k)
                    return np.abs(Y - A @ C).sum()
                
                theta0 = C_ls.reshape(-1)
                res = minimize(L1_norm_error, theta0, method="Powell",
                               options={"maxiter": 50, "xtol": 1e-6, "ftol": 1e-6})
                
                if res.success:
                    coeffs = res.x.reshape(2, k)
                else:
                    print("[WARN]: fall back to LS, iter = ", i)
                    coeffs = C_ls

            # predict positions
            t_now = x[-1]
            pose = np.array([t_now, 1.0]) @ coeffs
            pose_delay = np.array([t_now - tau, 1.0]) @ coeffs
            dist = np.linalg.norm(pose - pose_delay)

            # store the values 

            velocity_f.append(dist/tau)
            time_f.append(t_now)
            pose_f.append(pose)

            # remove the oldest info for next iter
            x.pop(0)
            y.pop(0)
    
    return velocity_f, time_f, pose_f

normalize_t = t162-t162[0]

dt_fix = 1/34
dx_1, dt_1 = estimate_velocity(p162_o, normalize_t, n=1)
dx_10, dt_10 = estimate_velocity(p162_o, normalize_t, n=10)
dx_100, dt_100 = estimate_velocity(p162_o, normalize_t, n=100)

velocity_f, time_f, _ = least_square_filter(p162_o, normalize_t, 
                                            filter_buffer=15, tau=0.04, 
                                            ROBUST_L1=False)

plt.figure(); ms = 2.5
plt.plot(normalize_t[1:], dx_1/dt_fix, '.', markersize=ms, label='1. fixed dt')
plt.plot(normalize_t[1:], dx_1/dt_1, '.', markersize=ms, label='2. varying dt + window 1')
plt.plot(normalize_t[10:], dx_10/dt_10, '.', markersize=ms, label='3. varying dt + window 10')
plt.plot(time_f, velocity_f, '.', markersize=ms, label='4. fixed dt + least square fit with window 10')
# plt.plot(normalize_t[100:], dx_100/dt_100, '.', markersize=ms, label='4. varying dt + window 100')
plt.grid(); plt.legend(loc='lower center', fontsize=8); plt.xlabel('t (s)'); plt.ylabel('v (m/s)'); plt.ylim(0, 0.3)
# Out:
# (0.0, 0.3)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Mocap v.s. Camera on spacing error
# The goal is to check the camera detection quality

# %%
'''
Mocap data process
'''
t162, p162_m = read_pose_from_bag(bag,
                                    '/vrpn_client_node/bot162/pose',
                                    'pose.position.x',
                                    'pose.position.y')
t205, p205_m = read_pose_from_bag(bag,
                                    '/vrpn_client_node/bot205/pose',
                                    'pose.position.x',
                                    'pose.position.y')
# trim mocap data to get spacing error
t162_t, p162_t, t205_t, p205_t = equal_trim_to_match(t162, p162_m, t205, p205_m)

# Spacing error from mocap (0.1)
error_m = np.linalg.norm(p162_t - p205_t, axis=1)
error_m -= error_m[0]
t_m = np.linspace(0, 1, len(error_m), dtype=float)
# Out:
# read pose & time /vrpn_client_node/bot162/pose (5952, 2)
# read pose & time /vrpn_client_node/bot205/pose (5910, 2)

# %%
# Spacing error from camera
topic_msg = pd.read_csv(bag.message_by_topic('/tbot162/controller_log_info'))
error_c = topic_msg['data_0'].to_numpy()
t_c = np.linspace(0, 1, len(error_c), dtype=float)

_, t_c_f, e_c_f = least_square_filter(error_c.reshape(-1, 1), t_c, 
                                      filter_buffer=30, tau=0.04, 
                                      ROBUST_L1=False)

# %matplotlib inline
# %matplotlib widget
plt.figure()
plt.plot(t_m, error_m, '.', markersize=ms, label='mocap')
plt.plot(t_c, error_c, '.', markersize=ms, label='camera (raw)')
# plt.plot(t_c_f, e_c_f, '.', markersize=ms, label='camera (filtered)')
plt.grid(); plt.legend(); plt.ylim(-0.01, 0.4)
plt.xlabel('Normalized time'); plt.ylabel('spacing Error')
# Out:
# Text(0, 0.5, 'spacing Error')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Spacing error from camera
topic_msg = pd.read_csv(bag.message_by_topic('/tbot162/controller_log_info'))
t_d = topic_msg['data_3'].to_numpy()
s_d = topic_msg['data_4'].to_numpy()
e_d = topic_msg['data_5'].to_numpy()
r_t = topic_msg['data_6'].to_numpy()
t = np.linspace(0, 1, len(r_t), dtype=float)

"""
    msg.data.push_back(dbg.t_d_last);         // 3  -         
    msg.data.push_back(dbg.s_d_last);         // 4  - 
    msg.data.push_back(dbg.e_d_last);         // 5  - 
    msg.data.push_back(dbg.r_t_last);         // 6  - 
"""
# %matplotlib inline
# %matplotlib widget
plt.figure()
plt.plot(t, t_d, '.', markersize=ms, label='t_d')
plt.plot(t, s_d, '.', markersize=ms, label='s_d')
plt.plot(t, e_d, '.', markersize=ms, label='e_d')
plt.plot(t, r_t, '.', markersize=ms, label='r_t')
plt.grid(); plt.legend(); plt.ylim(-0.25, 0.25)
plt.xlabel('Normalized time'); plt.ylabel('DSR command')
# Out:
# Text(0, 0.5, 'DSR command')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Spacing error from camera
topic_msg = pd.read_csv(bag.message_by_topic('/tbot162/controller_log_info'))
t_d = topic_msg['data_3'].to_numpy()
s_d = topic_msg['data_4'].to_numpy()
e_d = topic_msg['data_5'].to_numpy()
r_t = topic_msg['data_6'].to_numpy()
t = np.linspace(0, 1, len(r_t), dtype=float)

"""
    msg.data.push_back(dbg.t_d_last);         // 3  -         
    msg.data.push_back(dbg.s_d_last);         // 4  - 
    msg.data.push_back(dbg.e_d_last);         // 5  - 
    msg.data.push_back(dbg.r_t_last);         // 6  - 
"""
# %matplotlib inline
# %matplotlib widget
plt.figure()
plt.plot(t, t_d, '.', markersize=ms, label='t_d')
plt.plot(t, s_d, '.', markersize=ms, label='s_d')
plt.plot(t, e_d, '.', markersize=ms, label='e_d')
plt.plot(t, r_t, '.', markersize=ms, label='r_t')
plt.grid(); plt.legend(); plt.ylim(-0.25, 0.25)
plt.xlabel('Normalized time'); plt.ylabel('DSR command')
# Out:
# Text(0, 0.5, 'DSR command')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Spacing error from camera
topic_msg = pd.read_csv(bag.message_by_topic('/tbot162/controller_log_info'))
t_d = topic_msg['data_3'].to_numpy()
s_d = topic_msg['data_4'].to_numpy()
e_d = topic_msg['data_5'].to_numpy()
r_t = topic_msg['data_6'].to_numpy()
t = np.linspace(0, 1, len(r_t), dtype=float)

"""
    msg.data.push_back(dbg.t_d_last);         // 3  -         
    msg.data.push_back(dbg.s_d_last);         // 4  - 
    msg.data.push_back(dbg.e_d_last);         // 5  - 
    msg.data.push_back(dbg.r_t_last);         // 6  - 
"""
# %matplotlib inline
# %matplotlib widget
plt.figure()
plt.plot(t, t_d, '.', markersize=ms, label='t_d')
plt.plot(t, s_d, '.', markersize=ms, label='s_d')
plt.plot(t, e_d, '.', markersize=ms, label='e_d')
plt.plot(t, r_t, '.', markersize=ms, label='r_t')
plt.grid(); plt.legend(); plt.ylim(-0.25, 0.25)
plt.xlabel('Normalized time'); plt.ylabel('DSR command')
# Out:
# Text(0, 0.5, 'DSR command')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Spacing error from camera
topic_msg = pd.read_csv(bag.message_by_topic('/tbot162/controller_log_info'))
t_d = topic_msg['data_3'].to_numpy()
s_d = topic_msg['data_4'].to_numpy()
e_d = topic_msg['data_5'].to_numpy()
r_t = topic_msg['data_6'].to_numpy()
t = np.linspace(0, 1, len(r_t), dtype=float)

"""
    msg.data.push_back(dbg.t_d_last);         // 3  -         
    msg.data.push_back(dbg.s_d_last);         // 4  - 
    msg.data.push_back(dbg.e_d_last);         // 5  - 
    msg.data.push_back(dbg.r_t_last);         // 6  - 
"""
# %matplotlib inline
# %matplotlib widget
plt.figure()
plt.plot(t, t_d, '.', markersize=ms, label='t_d')
plt.plot(t, s_d, '.', markersize=ms, label='s_d')
plt.plot(t, e_d, '.', markersize=ms, label='e_d')
plt.plot(t, r_t, '.', markersize=ms, label='r_t')
plt.grid(); plt.legend(); plt.ylim(-0.25, 0.25)
plt.xlabel('Normalized time'); plt.ylabel('DSR command')
# Out:
# Text(0, 0.5, 'DSR command')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np

# Raw ROS-like times around 1.76369e9 with 40 ms steps
t64 = np.array([1.76369e9 + 0.04*k for k in range(6)], dtype=np.float64)

# Case 1: shove them straight into float32 (poor scaling)
t32_bad = t64.astype(np.float32)
print("diff bad (float32 on raw):", np.diff(t32_bad))
# -> diff bad: [0. 0. 0. 0. 0.]   # 0.04 s steps vanished

# Case 2: shift first, then cast (well-scaled)
t32_good = (t64 - t64[0]).astype(np.float32)
print("diff good (float32 after shift):", np.diff(t32_good))
# -> diff good: [0.03999996 0.03999996 0.03999996 0.0400002  0.03999996]
